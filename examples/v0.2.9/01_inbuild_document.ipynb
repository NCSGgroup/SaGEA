# %% [markdown]
# # sagea.SHC.io

# %%
import sagea

print(sagea.SHC.io.help())
# Out:
# SHC.io accessor
# Current context: class
#
# Below are class methods:
#   Recommended usage: SHC.io.<method_name>(...)
#   - SHC.io.from_gfc(filepath: 'str | Path | Sequence[str | Path]', lmax: 'int', key: 'str' = 'gfc', cols=None, normalization: 'str' = '4pi', dates: 'Sequence[datetime.date] | None' = None, attrs: 'dict | None' = None) -> "'SHC'"
#       Read SHC from one or multiple .gfc files.
#       Doc:
#         Read SHC from one or multiple GFC files.
#
# Below are instance methods:
#   Recommended usage: shc.io.<method_name>(...)
#   - shc.io.save_file(filepath: 'str | Path', index: 'int', header: 'str | None' = None, key: 'str | None' = None, overwrite: 'bool' = False, make_parent: 'bool' = True) -> 'None'
#       Save a .gfc file for a given-index set of coefficients.
#       Doc:
#         Save one epoch of SHC coefficients to a text .gfc-like file.

# %% [markdown]
# # sagea.SHC.generator

# %%
import sagea

print(sagea.SHC.generate.help())
# Out:
# SHC.generate accessor
# Current context: class
#
# Below are class methods:
#   Recommended usage: SHC.generate.<method_name>(...)
#   - SHC.generate.from_array(cs, normalization: 'str' = '4pi', dates: 'Sequence[dt.date] | None' = None, attrs: 'dict | None' = None) -> "'SHC'"
#       Generate SHC instance with a given 1D or 2D array. Equivalent to SHC(...).
#       Doc:
#         Generate SHC instance from array.
#   - SHC.generate.from_trend(shc_trend: "'SHC'", dates: 'Sequence[dt.date]', ref_time: 'dt.date | None' = None) -> "'SHC'"
#       Generate SHC time series from a trend SHC, for example a GIA model.
#       Doc:
#         Generate SHC time series from a trend SHC.
#
#         C(t) = C_rate * (t - t_ref)
#   - SHC.generate.normal_from_vcm(vcm: 'np.ndarray', nsample: 'int' = 1, mean: "'SHC | None'" = None) -> "'SHC'"
#       Generate SHC sample(s) from VCM assuming Gaussian distribution.
#       Doc:
#         Generate random SHC samples from variance-covariance matrix.
#
# ...

# %% [markdown]
# # sagea.SHC.filter

# %%
import sagea

print(sagea.SHC.filter.help())
# Out:
# SHC.filter accessor
# Current context: class
#
# Below are class methods:
#   Recommended usage: SHC.filter.<method_name>(...)
#   - SHC.filter.available() -> 'dict[str, list[str]]'
#       Return registered filter methods grouped by method kind.
#       Doc:
#         Return all registered filter methods grouped by kind.
#
#         Returns
#         -------
#         dict
#             Example:
#
#             {
#                 "class": ["available"],
#                 "instance": ["gaussian", "fan", "ddk", ...],
#             }
#
# Below are instance methods:
#   Recommended usage: shc.filter.<method_name>(...)
#   - shc.filter.gaussian(radius: 'int', *, inplace: 'bool' = False) -> "'SHC'"
#       Gaussian filter, see Wahr et al., 1998, https://doi.org/10.1029/98JB02844
#       Doc:
#         Apply Gaussian smoothing filter.
#
#         Parameters
#         ----------
#         radius:
#             Smoothing radius in kilometers.
#         inplace:
# ...
